# %%
# Adjust the working directly to import packages using the root package
import sys
import os
notebook_dir = os.getcwd()
print(notebook_dir)
parent_dir = os.path.dirname(notebook_dir)
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
# Out:
# /Users/ashrafahmed/workspace/singular-learning-theory/code/python/notebooks/slt-examples

# %%
from sklearn_ext.mixture.binomial_mixture import BinomialMixture2
import pytensor
import pytensor.tensor as pt

bmm = BinomialMixture2(name="bmm", w=[0.1, 0.9], prob=[0.1, 0.3], n_trials=100)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn_ext.mixture.binomial_mixture import BinomialMixture2
#       2 import pytensor
#       3 import pytensor.tensor as pt
#
# File ~/workspace/singular-learning-theory/code/python/notebooks/sklearn_ext/mixture/binomial_mixture.py:4
#       2 from scipy.stats import binom, chi2
#       3 from scipy.special import logsumexp
# ----> 4 from sklearn.mixture import Mixture
#       5 from sklearn.mixture._base import BaseMixture
#       6 from sklearn.utils.validation import check_X_y, check_array
#
# ImportError: cannot import name 'Mixture' from 'sklearn.mixture' (/Users/ashrafahmed/workspace/singular-learning-theory/code/python/.venv/lib/python3.12/site-packages/sklearn/mixture/__init__.py)
