# %%
from pathlib import Path
from os import environ


# IN_COLAB = False
# if "DRIVE_HOME" in environ:
  # ROOT = Path(f"{environ.get("DRIVE_HOME")}/colab/outputs/waterloo-slt-reading-group")
# else:
ROOT = Path(f"{Path.cwd().parents[1]}/outputs")
basedir = Path(f"{ROOT}/mixture/poisson2d")
datadir = Path(f"{basedir}/data")
outputdir = Path(f"{basedir}/rlct")

if not outputdir.exists():
  outputdir.mkdir(exist_ok=True)
  print(f"Created {outputdir}!")

print(f"Using datadir={datadir}")
print(f"Using outputdir={outputdir}")
# Out:
# Using datadir=/Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixture/poisson2d/data
# Using outputdir=/Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixture/poisson2d/rlct

# %%
import pandas as pd

dgps_file = f"{datadir}/dgp.csv"
dgps=pd.read_csv(dgps_file, index_col=0).reset_index()
dgps.head()
# Out:
#          dsid  m0  m1    w0    w1
# 0     regular  15   1  0.75  0.25
# 1  e-singular  10   5  0.75  0.25
# 2   singular1  10   5  1.00  0.00
# 3   singular2   5   5  0.75  0.25

# %%
from sklearn_extensions.mixpoisson import PoissonMixture
from scipy_extensions import mixpoisson


def find_truth_by_dsid(dsid: str):
  dgp = dgps.query(f"dsid=='{dsid}'")
  truth = dgp[["m0", "m1", "w0", "w1"]].iloc[0].tolist()
  return truth

def rlct_by_dsid(dsid: str):
  truth = find_truth_by_dsid(dsid)
  n_components = np.ceil(len(truth)/2)
  rlct = None
  match dsid:
    case "regular" | "e-singular":
      rlct = (n_components*2-1)/2
    case "singular1" | "singular2":
      rlct = 1
    case _:
      raise Exception(f"Uknown dsid={dsid}")

  return rlct

def approx_free_energy_by_dsid(dsid, X):
  n=len(X)
  
  average_log_likelihood = None
  model = PoissonMixture(n_components=3, enforce_ordering=False)
  input_data = np.column_stack([X])
  model.fit(input_data)
  mle, _ = model.point_estimate()
  log_p = mixpoisson.logpmf(weights=[mle[2], 1-mle[2]], mus=[mle[0], mle[1]], x=X) # sample likelihood under the mle
  average_log_likelihood = log_p.mean()

  afe = -n_obs*average_log_likelihood+rlct_by_dsid(dsid)*np.log(n_obs)
  return afe


def expected_free_energy_by_dsid(dsid, n, x_max=100):
  X = np.arange(0, x_max, 1)
  truth = find_truth_by_dsid(dsid)
  weights_0=truth[2:3]
  mus_0=truth[0:1]

  log_q = mixpoisson.logpmf(weights=weights_0, mus=mus_0, x=X)
  log_p = mixpoisson.logpmf(weights=weights_0, mus=mus_0, x=X)
  expected_log_likelihood = np.exp(log_q)*log_p
  second_order_term = rlct_by_dsid(dsid)*np.log(n)

  efe = -n * expected_log_likelihood.sum() + second_order_term
  return efe

# %%
import pandas as pd
import json
from pathlib import Path

results_file = Path(f"{outputdir}/estimators_data.csv")

# Load existing results if file exists
if results_file.exists():
  estimators_df = pd.read_csv(results_file)
  # Create a set of completed (run, regime, dsid) tuples for fast lookup
  completed = set(
      zip(estimators_df["trial"], estimators_df["regime"], estimators_df["dsid"], estimators_df["hypers"])
  )
  estimators_data = estimators_df.to_dict("records")
else:
  completed = set()
  estimators_data = []

def save_results():
  """Save current results to disk."""
  pd.DataFrame(estimators_data).to_csv(results_file, index=False)

# %%
from joblib import Parallel, delayed
import time

def run_single_dsid(dsid, run, regime, hypers, c, d, datadir, n_draws, n_tune, n_chains):
    dataset = pd.read_csv(f"{datadir}/{dsid}-{regime}.csv")
    X = dataset.iloc[:, run].to_numpy()
    n_obs = len(X)
    
    start = time.perf_counter()
    
    beta = c / np.log(n_obs)
    delta = d / np.log(n_obs)
    
    # First MCMC run at beta
    with TemperedPoissonMixture(X=X, beta=beta) as model:
        idata0 = model.sample(
            draws=n_draws,
            tune=n_tune,
            chains=n_chains,
            progressbar=False,
            nuts_sampler="nutpie",
            cores=1
        )
        weights = pmx.column_stack_vars(idata0, ["weights"])
        mus = pmx.column_stack_vars(idata0, ["mus"])
        log_likelihood = mixpoisson.log_likelihood(weights, mus, x=X)
        ll0 = log_likelihood.mean()
    
    diverging0 = idata0.sample_stats.diverging.values
    divs_per_chain0 = diverging0.sum(axis=1)
    mean_divergences0 = divs_per_chain0.mean()
    total_divergences0 = diverging0.sum()
    max_divergences0 = divs_per_chain0.max()
    tree_depth0 = idata0.sample_stats.depth.values.max()
    
    # Second MCMC run at beta + delta
    with TemperedPoissonMixture(X=X, beta=beta + delta) as model:
        idata1 = model.sample(
            draws=n_draws,
            tune=n_tune,
            chains=n_chains,
            progressbar=False,
            nuts_sampler="nutpie",
            cores=1
        )
        weights = pmx.column_stack_vars(idata1, ["weights"])
        mus = pmx.column_stack_vars(idata1, ["mus"])
        log_likelihood = mixpoisson.log_likelihood(weights, mus, x=X)
        ll1 = log_likelihood.mean()
    
    diverging1 = idata1.sample_stats.diverging.values
    divs_per_chain1 = diverging1.sum(axis=1)
    mean_divergences1 = divs_per_chain1.mean()
    total_divergences1 = diverging1.sum()
    max_divergences1 = divs_per_chain1.max()
    tree_depth1 = idata1.sample_stats.depth.values.max()
    
    rlct = (ll0 - ll1) / (1 / (beta + delta) - 1 / beta)
    end = time.perf_counter()
    
    print(f"run={run}, regime={regime}, c={c}, d={d}, dsid={dsid}, rlct_watanabe={rlct}, duration={end - start:.6f}")
    
    return {
        "dsid": dsid,
        "regime": regime,
        "n": regime,
        "trial": run,
        "rlct": rlct,
        "hypers": hypers,
        "name": "watanabe",
        "chains": n_chains,
        "draws": n_draws,
        "tune": n_tune,
        "mean_divergences": (mean_divergences0 + mean_divergences1) / 2,
        "total_divergences": total_divergences0 + total_divergences1,
        "max_divergences": max(max_divergences0, max_divergences1),
        "divergences_per_chain": divs_per_chain0.tolist() + divs_per_chain1.tolist(),
        "chain_tree_depth": max(tree_depth0, tree_depth1),
        "duration": end - start
    }

# %%
from pymc_extensions.tempered_mixpoisson import TemperedPoissonMixture
from pymc_extensions import pmx
from scipy_extensions import mixpoisson
from tqdm.notebook import tqdm
import pymc as pm
import numpy as np
import arviz as az
import time


n_components = 2
regimes = [50, 250, 5000]

# mcmc settings
n_tune=2500
n_draws=1500
n_chains=2
c_values=[1, 1, 1]
d_values=[1/10, 1, 10]

# read all the data so we can nicely loop 
for run in tqdm(range(1000), desc=f"runs "):
  # if run > 10:
  #   break
  for c_index, c in enumerate(c_values):
    d = d_values[c_index]
    hypers = f"c={c},d={d}"
    for regime in tqdm(regimes, desc="regimes"):
      # Filter to only incomplete dsids
      dsids_to_run = [
        dsid for dsid in dgps["dsid"].unique()
        if (run, regime, dsid, hypers) not in completed
      ]
      
      # Run in parallel
      results = Parallel(n_jobs=16)(  # adjust based on vCPUs
        delayed(run_single_dsid)(
          dsid, run, regime, hypers, c, d, datadir, n_draws, n_tune, n_chains
        )
        for dsid in dsids_to_run
      )
      
      # Collect results
      for result in results:
        estimators_data.append(result)
        completed.add((result["trial"], result["regime"], result["dsid"], result["hypers"]))
        
      # for dsid in dgps["dsid"].unique():
      #   dataset = pd.read_csv(f"{datadir}/{dsid}-{regime}.csv")
  
      #   X = dataset.iloc[:, run].to_numpy()
      #   n_obs = len(X)

      #   # Skip if already completed
      #   if (run, regime, dsid, hypers) in completed:
      #     print(f"skipped run={run}, dsid={dsid}, regime={regime}, hypers={hypers}")
      #     continue
      #   start = time.perf_counter()
  
      #   beta = c/np.log(n_obs)
      #   delta = d/np.log(n_obs)

      #   ll0 = None
      #   with TemperedPoissonMixture(X=X, beta=beta) as model:
      #     idata = model.sample(draws=n_draws, 
      #                          tune=n_tune, 
      #                          chains=n_chains, 
      #                          progressbar=False,
      #                          nuts_sampler="nutpie",
      #                          cores=2)  # or "blackjax"

      #     weights = pmx.column_stack_vars(idata, ["weights"])
      #     mus = pmx.column_stack_vars(idata, ["mus"])
      #     log_likelihood = mixpoisson.log_likelihood(weights, mus, x=X)
      #     ll0 = log_likelihood.mean()
  
      #   # Divergences are stored in sample_stats as a boolean array (chain, draw)
      #   diverging = idata.sample_stats.diverging.values
        
      #   # Divergences per chain
      #   divs_per_chain0 = diverging.sum(axis=1)  # array with one value per chain
        
      #   # Summary statistics
      #   mean_divergences0 = divs_per_chain0.mean()
      #   total_divergences0 = diverging.sum()
      #   max_divergences0 = divs_per_chain0.max()
      #   tree_depth0=idata.sample_stats.depth.values.max()

      #   ll1=None
      #   with TemperedPoissonMixture(X=X, beta=beta+delta) as model:
      #     idata = model.sample(draws=n_draws, 
      #                          tune=n_tune, 
      #                          chains=n_chains, 
      #                          progressbar=False,
      #                          nuts_sampler="nutpie",
      #                          cores=4)  # or "blackjax"

      #     weights = pmx.column_stack_vars(idata, ["weights"])
      #     mus = pmx.column_stack_vars(idata, ["mus"])
      #     log_likelihood = mixpoisson.log_likelihood(weights, mus, x=X)
      #     ll1 = log_likelihood.mean()

      #   # Divergences are stored in sample_stats as a boolean array (chain, draw)
      #   diverging = idata.sample_stats.diverging.values
        
      #   # Divergences per chain
      #   divs_per_chain1 = diverging.sum(axis=1)  # array with one value per chain
        
      #   # Summary statistics
      #   mean_divergences1 = divs_per_chain1.mean()
      #   total_divergences1 = diverging.sum()
      #   max_divergences1 = divs_per_chain1.max()
      #   tree_depth1=idata.sample_stats.depth.values.max()
        
      #   rlct=(ll0-ll1)/(1/(beta+delta)-1/beta)

      #   end = time.perf_counter()
      #   print(f"run={run}, regime={regime}, c={c},d={d}, dsid={dsid}, rlct_watanabe={rlct}, duration={end-start:.6f}")
        
      #   result = {
      #     "dsid": dsid,
      #     "regime": regime,
      #     "n": regime,
      #     "trial": run,
      #     "rlct": rlct,
      #     "hypers": hypers,
      #     "name": "watanabe",
      #     "chains": n_chains,
      #     "draws": n_draws,
      #     "tune": n_tune,
      #     "mean_divergences": (mean_divergences0+mean_divergences1)/2,
      #     "total_divergences": np.sum(total_divergences0, total_divergences1),
      #     "max_divergences": np.max(max_divergences0, max_divergences1),
      #     "divergences_per_chain": divs_per_chain0.tolist()+divs_per_chain1.tolist(),
      #     "chain_tree_depth": np.max([tree_depth0, tree_depth1]),
      #     "duration": end-start
      #   }
  
      #   estimators_data.append(result)
      #   completed.add((run, regime, dsid, hypers))
  
      # Save after each successful run
      save_results()
      # !git add "../../outputs/mixture/poisson2d/rlct/estimators_data.csv"
      # !git commit -m "more runs"
      # !git push
# Out:
# runs :   0%|          | 0/1000 [00:00<?, ?it/s]
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=0, dsid=regular, regime=50, hypers=c=1,d=0.1
# skipped run=0, dsid=e-singular, regime=50, hypers=c=1,d=0.1
# skipped run=0, dsid=singular1, regime=50, hypers=c=1,d=0.1
# skipped run=0, dsid=singular2, regime=50, hypers=c=1,d=0.1
# skipped run=0, dsid=regular, regime=250, hypers=c=1,d=0.1
# skipped run=0, dsid=e-singular, regime=250, hypers=c=1,d=0.1
# skipped run=0, dsid=singular1, regime=250, hypers=c=1,d=0.1
# skipped run=0, dsid=singular2, regime=250, hypers=c=1,d=0.1
# skipped run=0, dsid=regular, regime=5000, hypers=c=1,d=0.1
# skipped run=0, dsid=e-singular, regime=5000, hypers=c=1,d=0.1
# skipped run=0, dsid=singular1, regime=5000, hypers=c=1,d=0.1
# skipped run=0, dsid=singular2, regime=5000, hypers=c=1,d=0.1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=0, dsid=regular, regime=50, hypers=c=1,d=1
# skipped run=0, dsid=e-singular, regime=50, hypers=c=1,d=1
# skipped run=0, dsid=singular1, regime=50, hypers=c=1,d=1
# skipped run=0, dsid=singular2, regime=50, hypers=c=1,d=1
# skipped run=0, dsid=regular, regime=250, hypers=c=1,d=1
# skipped run=0, dsid=e-singular, regime=250, hypers=c=1,d=1
# skipped run=0, dsid=singular1, regime=250, hypers=c=1,d=1
# skipped run=0, dsid=singular2, regime=250, hypers=c=1,d=1
# skipped run=0, dsid=regular, regime=5000, hypers=c=1,d=1
# skipped run=0, dsid=e-singular, regime=5000, hypers=c=1,d=1
# skipped run=0, dsid=singular1, regime=5000, hypers=c=1,d=1
# skipped run=0, dsid=singular2, regime=5000, hypers=c=1,d=1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=1, dsid=regular, regime=50, hypers=c=1,d=0.1
# skipped run=1, dsid=e-singular, regime=50, hypers=c=1,d=0.1
# skipped run=1, dsid=singular1, regime=50, hypers=c=1,d=0.1
# skipped run=1, dsid=singular2, regime=50, hypers=c=1,d=0.1
# skipped run=1, dsid=regular, regime=250, hypers=c=1,d=0.1
# skipped run=1, dsid=e-singular, regime=250, hypers=c=1,d=0.1
# skipped run=1, dsid=singular1, regime=250, hypers=c=1,d=0.1
# skipped run=1, dsid=singular2, regime=250, hypers=c=1,d=0.1
# skipped run=1, dsid=regular, regime=5000, hypers=c=1,d=0.1
# skipped run=1, dsid=e-singular, regime=5000, hypers=c=1,d=0.1
# skipped run=1, dsid=singular1, regime=5000, hypers=c=1,d=0.1
# skipped run=1, dsid=singular2, regime=5000, hypers=c=1,d=0.1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=1, dsid=regular, regime=50, hypers=c=1,d=1
# skipped run=1, dsid=e-singular, regime=50, hypers=c=1,d=1
# skipped run=1, dsid=singular1, regime=50, hypers=c=1,d=1
# skipped run=1, dsid=singular2, regime=50, hypers=c=1,d=1
# skipped run=1, dsid=regular, regime=250, hypers=c=1,d=1
# skipped run=1, dsid=e-singular, regime=250, hypers=c=1,d=1
# skipped run=1, dsid=singular1, regime=250, hypers=c=1,d=1
# skipped run=1, dsid=singular2, regime=250, hypers=c=1,d=1
# skipped run=1, dsid=regular, regime=5000, hypers=c=1,d=1
# skipped run=1, dsid=e-singular, regime=5000, hypers=c=1,d=1
# skipped run=1, dsid=singular1, regime=5000, hypers=c=1,d=1
# skipped run=1, dsid=singular2, regime=5000, hypers=c=1,d=1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=2, dsid=regular, regime=50, hypers=c=1,d=0.1
# skipped run=2, dsid=e-singular, regime=50, hypers=c=1,d=0.1
# skipped run=2, dsid=singular1, regime=50, hypers=c=1,d=0.1
# skipped run=2, dsid=singular2, regime=50, hypers=c=1,d=0.1
# skipped run=2, dsid=regular, regime=250, hypers=c=1,d=0.1
# skipped run=2, dsid=e-singular, regime=250, hypers=c=1,d=0.1
# skipped run=2, dsid=singular1, regime=250, hypers=c=1,d=0.1
# skipped run=2, dsid=singular2, regime=250, hypers=c=1,d=0.1
# skipped run=2, dsid=regular, regime=5000, hypers=c=1,d=0.1
# skipped run=2, dsid=e-singular, regime=5000, hypers=c=1,d=0.1
# skipped run=2, dsid=singular1, regime=5000, hypers=c=1,d=0.1
# skipped run=2, dsid=singular2, regime=5000, hypers=c=1,d=0.1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=2, dsid=regular, regime=50, hypers=c=1,d=1
# skipped run=2, dsid=e-singular, regime=50, hypers=c=1,d=1
# skipped run=2, dsid=singular1, regime=50, hypers=c=1,d=1
# skipped run=2, dsid=singular2, regime=50, hypers=c=1,d=1
# skipped run=2, dsid=regular, regime=250, hypers=c=1,d=1
# skipped run=2, dsid=e-singular, regime=250, hypers=c=1,d=1
# skipped run=2, dsid=singular1, regime=250, hypers=c=1,d=1
# skipped run=2, dsid=singular2, regime=250, hypers=c=1,d=1
# skipped run=2, dsid=regular, regime=5000, hypers=c=1,d=1
# skipped run=2, dsid=e-singular, regime=5000, hypers=c=1,d=1
# skipped run=2, dsid=singular1, regime=5000, hypers=c=1,d=1
# skipped run=2, dsid=singular2, regime=5000, hypers=c=1,d=1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=3, dsid=regular, regime=50, hypers=c=1,d=0.1
# skipped run=3, dsid=e-singular, regime=50, hypers=c=1,d=0.1
# skipped run=3, dsid=singular1, regime=50, hypers=c=1,d=0.1
# skipped run=3, dsid=singular2, regime=50, hypers=c=1,d=0.1
# skipped run=3, dsid=regular, regime=250, hypers=c=1,d=0.1
# skipped run=3, dsid=e-singular, regime=250, hypers=c=1,d=0.1
# skipped run=3, dsid=singular1, regime=250, hypers=c=1,d=0.1
# skipped run=3, dsid=singular2, regime=250, hypers=c=1,d=0.1
# skipped run=3, dsid=regular, regime=5000, hypers=c=1,d=0.1
# skipped run=3, dsid=e-singular, regime=5000, hypers=c=1,d=0.1
# skipped run=3, dsid=singular1, regime=5000, hypers=c=1,d=0.1
# skipped run=3, dsid=singular2, regime=5000, hypers=c=1,d=0.1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# skipped run=3, dsid=regular, regime=50, hypers=c=1,d=1
# skipped run=3, dsid=e-singular, regime=50, hypers=c=1,d=1
# skipped run=3, dsid=singular1, regime=50, hypers=c=1,d=1
# skipped run=3, dsid=singular2, regime=50, hypers=c=1,d=1
# skipped run=3, dsid=regular, regime=250, hypers=c=1,d=1
# skipped run=3, dsid=e-singular, regime=250, hypers=c=1,d=1
# skipped run=3, dsid=singular1, regime=250, hypers=c=1,d=1
# skipped run=3, dsid=singular2, regime=250, hypers=c=1,d=1
# skipped run=3, dsid=regular, regime=5000, hypers=c=1,d=1
# skipped run=3, dsid=e-singular, regime=5000, hypers=c=1,d=1
# skipped run=3, dsid=singular1, regime=5000, hypers=c=1,d=1
# skipped run=3, dsid=singular2, regime=5000, hypers=c=1,d=1
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=50, c=1,d=0.1, dsid=regular, rlct_watanabe=1.5677074704349063, duration=4.480094
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=50, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.4362339467861567, duration=7.480732
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=50, c=1,d=0.1, dsid=singular1, rlct_watanabe=1.643634134507061, duration=7.851737
# skipped run=4, dsid=singular2, regime=50, hypers=c=1,d=0.1
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=250, c=1,d=0.1, dsid=regular, rlct_watanabe=1.9270307285317865, duration=5.063792
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=250, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.019037068337982, duration=10.110244
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=250, c=1,d=0.1, dsid=singular1, rlct_watanabe=0.15624910222895136, duration=13.917094
# skipped run=4, dsid=singular2, regime=250, hypers=c=1,d=0.1
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=0.1, dsid=regular, rlct_watanabe=1.371782415879527, duration=29.477673
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=0.1, dsid=e-singular, rlct_watanabe=0.6276427934110753, duration=47.972312
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=0.1, dsid=singular1, rlct_watanabe=1.2248001886352493, duration=209.666361
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=0.1, dsid=singular2, rlct_watanabe=0.41934088575457407, duration=168.031044
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=50, c=1,d=1, dsid=regular, rlct_watanabe=1.3327911847310745, duration=4.537230
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=50, c=1,d=1, dsid=e-singular, rlct_watanabe=1.2483949483024763, duration=7.238517
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=50, c=1,d=1, dsid=singular1, rlct_watanabe=1.1292266234333557, duration=7.964043
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=50, c=1,d=1, dsid=singular2, rlct_watanabe=1.040598927332679, duration=6.050911
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=250, c=1,d=1, dsid=regular, rlct_watanabe=1.4586939312309368, duration=5.048488
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=250, c=1,d=1, dsid=e-singular, rlct_watanabe=1.4536752598344314, duration=8.735659
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=250, c=1,d=1, dsid=singular1, rlct_watanabe=0.9472327151301745, duration=16.360207
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=250, c=1,d=1, dsid=singular2, rlct_watanabe=1.0034173801966666, duration=9.773751
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=1, dsid=regular, rlct_watanabe=1.5070474634467603, duration=28.840533
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=1, dsid=e-singular, rlct_watanabe=1.5551981304442404, duration=44.988939
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=1, dsid=singular1, rlct_watanabe=0.8609513825049738, duration=175.718212
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=4, regime=5000, c=1,d=1, dsid=singular2, rlct_watanabe=0.845994102469482, duration=182.025707
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=0.1, dsid=regular, rlct_watanabe=1.6324722942360603, duration=7.656232
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.103847161000257, duration=6.058879
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=0.1, dsid=singular1, rlct_watanabe=1.2910099163599045, duration=7.809414
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=0.1, dsid=singular2, rlct_watanabe=1.6889379327917502, duration=6.028633
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=0.1, dsid=regular, rlct_watanabe=1.4384562304214141, duration=5.633191
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=0.1, dsid=e-singular, rlct_watanabe=0.6886062489937087, duration=10.831148
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=0.1, dsid=singular1, rlct_watanabe=1.050062729967624, duration=14.362367
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=0.1, dsid=singular2, rlct_watanabe=1.0073516841559798, duration=10.033908
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=0.1, dsid=regular, rlct_watanabe=1.6030460866386562, duration=31.680985
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=0.1, dsid=e-singular, rlct_watanabe=2.4026516747795172, duration=43.212740
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=0.1, dsid=singular1, rlct_watanabe=0.728255581497529, duration=152.742972
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=0.1, dsid=singular2, rlct_watanabe=0.3212664046121449, duration=157.266023
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=1, dsid=regular, rlct_watanabe=1.3624931348120441, duration=4.489850
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=1, dsid=e-singular, rlct_watanabe=1.4647006887166956, duration=8.545790
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=1, dsid=singular1, rlct_watanabe=1.1431759511250086, duration=8.861858
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=50, c=1,d=1, dsid=singular2, rlct_watanabe=1.0798037360889816, duration=6.502580
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=1, dsid=regular, rlct_watanabe=1.466477961441562, duration=5.023740
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=1, dsid=e-singular, rlct_watanabe=0.9994749345783884, duration=11.109029
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=1, dsid=singular1, rlct_watanabe=1.0251685969083346, duration=13.705522
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=250, c=1,d=1, dsid=singular2, rlct_watanabe=0.9709383749774162, duration=9.905348
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=1, dsid=regular, rlct_watanabe=1.4434372655613499, duration=30.964019
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=1, dsid=e-singular, rlct_watanabe=1.503302714436581, duration=50.448136
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=1, dsid=singular1, rlct_watanabe=0.8149489005151985, duration=168.396915
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=5, regime=5000, c=1,d=1, dsid=singular2, rlct_watanabe=0.8067879138649111, duration=146.031400
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=50, c=1,d=0.1, dsid=regular, rlct_watanabe=0.9295516938649447, duration=4.280082
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=50, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.0675562998836745, duration=7.376605
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=50, c=1,d=0.1, dsid=singular1, rlct_watanabe=1.443180259038653, duration=8.334832
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=50, c=1,d=0.1, dsid=singular2, rlct_watanabe=0.8318649463879387, duration=6.316308
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=250, c=1,d=0.1, dsid=regular, rlct_watanabe=2.3248137127432362, duration=4.942652
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=250, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.7018396224136891, duration=13.370857
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=250, c=1,d=0.1, dsid=singular1, rlct_watanabe=1.5349182315017538, duration=13.776444
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=250, c=1,d=0.1, dsid=singular2, rlct_watanabe=0.6657221943971043, duration=9.999716
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=5000, c=1,d=0.1, dsid=regular, rlct_watanabe=1.0945960903448582, duration=29.347867
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=6, regime=5000, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.4775139005829716, duration=45.040030
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# ...
# run=10, regime=50, c=1,d=0.1, dsid=regular, rlct_watanabe=1.5598428009548166, duration=4.638697
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=50, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.154993924050846, duration=8.347755
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=50, c=1,d=0.1, dsid=singular1, rlct_watanabe=1.0154722518030448, duration=19.757905
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=50, c=1,d=0.1, dsid=singular2, rlct_watanabe=1.2330447233512718, duration=6.405363
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=0.1, dsid=regular, rlct_watanabe=1.5055916439358263, duration=6.534796
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.8288915972337019, duration=9.446860
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=0.1, dsid=singular1, rlct_watanabe=0.8532624910032217, duration=15.057514
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=0.1, dsid=singular2, rlct_watanabe=0.7498335964211149, duration=11.020883
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=0.1, dsid=regular, rlct_watanabe=1.8655325572384076, duration=33.646224
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=0.1, dsid=e-singular, rlct_watanabe=1.3982278741177625, duration=45.748818
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=0.1, dsid=singular1, rlct_watanabe=0.3957201732589444, duration=160.092557
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=0.1, dsid=singular2, rlct_watanabe=0.9683563783500064, duration=162.146420
# regimes:   0%|          | 0/3 [00:00<?, ?it/s]
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=50, c=1,d=1, dsid=regular, rlct_watanabe=1.4812373952339828, duration=4.479541
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=50, c=1,d=1, dsid=e-singular, rlct_watanabe=1.1066294479486105, duration=7.234263
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=50, c=1,d=1, dsid=singular1, rlct_watanabe=1.0648990570818346, duration=8.185075
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=50, c=1,d=1, dsid=singular2, rlct_watanabe=0.9210422818887272, duration=6.759137
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=1, dsid=regular, rlct_watanabe=1.465415507247145, duration=5.208959
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=1, dsid=e-singular, rlct_watanabe=1.6228237361112103, duration=8.204309
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=1, dsid=singular1, rlct_watanabe=1.0488076872559138, duration=21.742250
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=250, c=1,d=1, dsid=singular2, rlct_watanabe=0.8461072885157414, duration=11.684365
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=1, dsid=regular, rlct_watanabe=1.3992065950003045, duration=34.246411
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=1, dsid=e-singular, rlct_watanabe=1.455812198185738, duration=56.604260
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=1, dsid=singular1, rlct_watanabe=0.8504227741452365, duration=212.419977
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# run=10, regime=5000, c=1,d=1, dsid=singular2, rlct_watanabe=0.7431293284034034, duration=196.811913

# %%
rlct_estimates_df = pd.DataFrame(estimators_data)
rlct_estimates_df
# Out:
#            dsid  regime     n  trial      rlct     hypers      name  chains  \
# 0     singular2    5000  5000      0  0.959683  c=1,d=0.1  watanabe       4
# 1     singular2    5000  5000      0  0.839289    c=1,d=1  watanabe       4
# 2     singular2    5000  5000      1  0.816095  c=1,d=0.1  watanabe       4
# 3     singular2    5000  5000      1  0.905477    c=1,d=1  watanabe       4
# 4     singular2    5000  5000      2  1.453012  c=1,d=0.1  watanabe       4
# ..          ...     ...   ...    ...       ...        ...       ...     ...
# 416   singular2     250   250      4  0.874483   c=1,d=10  watanabe       2
# 417     regular    5000  5000      4  1.529915   c=1,d=10  watanabe       2
# 418  e-singular    5000  5000      4  1.609254   c=1,d=10  watanabe       2
# 419   singular1    5000  5000      4  0.942860   c=1,d=10  watanabe       2
# 420   singular2    5000  5000      4  0.821335   c=1,d=10  watanabe       2
#
#      draws  tune  mean_divergences  total_divergences  max_divergences  \
# 0     1000  4000               0.0                  0                0
# 1     1000  4000               0.0                  0                0
# 2     1000  4000               0.0                  0                0
# 3     1000  4000               0.0                  0                0
# 4     1000  4000               0.0                  0                0
# ..     ...   ...               ...                ...              ...
# 416   1500  2500               0.0                  0                0
# 417   1500  2500               0.0                  0                0
# 418   1500  2500               0.0                  0                0
# 419   1500  2500               0.0                  0                0
# 420   1500  2500               0.0                  0                0
#
#         divergences_per_chain  chain_tree_depth    duration
# 0    [0, 0, 0, 0, 0, 0, 0, 0]                10         NaN
# 1    [0, 0, 0, 0, 0, 0, 0, 0]                10         NaN
# 2    [0, 0, 0, 0, 0, 0, 0, 0]                10         NaN
# 3    [0, 0, 0, 0, 0, 0, 0, 0]                10         NaN
# 4    [0, 0, 0, 0, 0, 0, 0, 0]                10         NaN
# ..                        ...               ...         ...
# 416              [0, 0, 0, 0]                 9   31.131667
# 417              [0, 0, 0, 0]                 5   68.188593
# 418              [0, 0, 0, 0]                 7   90.867187
# 419              [0, 0, 0, 0]                10  161.813717
# 420              [0, 0, 0, 0]                10  189.946178
#
# [421 rows x 16 columns]

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np

# dsids = rlct_estimates_df['dsid'].unique()
# n_values = sorted(rlct_estimates_df['n'].unique())

# g = sns.FacetGrid(
#     rlct_estimates_df, 
#     row='dsid', 
#     col='n', 
#     height=4, 
#     aspect=1.2,
#     sharey='row',
#     row_order=dsids[::-1],
#     col_order=n_values
# )

# g.map_dataframe(
#     sns.boxplot, 
#     x='hypers', 
#     y='rlct', 
#     hue='hypers',
#     palette='Set2',
#     legend=False,
#     fliersize=2
# )

# # Add true RLCT lines to each row
# for i, dsid in enumerate(dsids[::-1]):
#     true_rlct = rlct_by_dsid(dsid)
#     for j, n in enumerate(n_values):
#         ax = g.axes[i, j]
#         ax.axhline(true_rlct, color='red', linestyle='--', linewidth=2)

# g.set_axis_labels('', 'RLCT estimate')
# g.set_titles(row_template='{row_name}', col_template='n = {col_name}')

# for ax in g.axes.flat:
#     ax.tick_params(axis='x', rotation=45)

# plt.suptitle('RLCT Estimation by Hyperparameters', y=1.02)
# plt.tight_layout()
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

dsids = rlct_estimates_df['dsid'].unique()
n_values = sorted(rlct_estimates_df['n'].unique())

g = sns.FacetGrid(
    rlct_estimates_df, 
    row='dsid', 
    col='n', 
    height=4, 
    aspect=1.2,
    sharey='row',
    row_order=dsids[::-1],
    col_order=n_values
)

g.map_dataframe(
    sns.violinplot, 
    x='hypers', 
    y='rlct', 
    hue='hypers',
    palette='Set2',
    legend=False,
    cut=0,  # Don't extend beyond data range
    inner='quart'  # Show quartiles inside violin
)

# Add true RLCT lines to each row
for i, dsid in enumerate(dsids[::-1]):
    true_rlct = rlct_by_dsid(dsid)
    for j, n in enumerate(n_values):
        ax = g.axes[i, j]
        ax.axhline(true_rlct, color='red', linestyle='--', linewidth=2)

g.set_axis_labels('', 'RLCT estimate')
g.set_titles(row_template='{row_name}', col_template='n = {col_name}')

for ax in g.axes.flat:
    ax.tick_params(axis='x', rotation=45)

plt.suptitle('RLCT Estimation by Hyperparameters', y=1.02)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Compute summary statistics
summary = rlct_estimates_df.groupby(['dsid', 'n', 'hypers']).agg(
    mean_rlct=('rlct', 'mean'),
    std_rlct=('rlct', 'std'),
    median_rlct=('rlct', 'median')
).reset_index()

# Add true RLCT and compute bias/rmse
summary['true_rlct'] = summary['dsid'].apply(rlct_by_dsid)
summary['bias'] = summary['mean_rlct'] - summary['true_rlct']
summary['rmse'] = np.sqrt(summary['bias']**2 + summary['std_rlct']**2)

dsids = ['regular', 'e-singular', 'singular1', 'singular2']

fig, axes = plt.subplots(2, len(dsids), figsize=(4*len(dsids), 8), sharex=True)

for j, dsid in enumerate(dsids):
    data = summary[summary['dsid'] == dsid]
    
    # Top row: Bias
    ax = axes[0, j]
    sns.lineplot(
        data=data,
        x='n',
        y='bias',
        hue='hypers',
        marker='o',
        ax=ax
    )
    ax.axhline(0, color='red', linestyle='--', linewidth=1)
    ax.set_xscale('log')
    ax.set_title(dsid, fontweight='bold')
    ax.set_xlabel('')
    ax.set_ylabel('Bias' if j == 0 else '')
    
    if j < len(dsids) - 1:
        ax.get_legend().remove()
    else:
        ax.legend(title='hypers', bbox_to_anchor=(1.02, 1), loc='upper left')
    
    # Bottom row: RMSE
    ax = axes[1, j]
    sns.lineplot(
        data=data,
        x='n',
        y='rmse',
        hue='hypers',
        marker='o',
        ax=ax
    )
    ax.set_xscale('log')
    ax.set_xlabel('n')
    ax.set_ylabel('RMSE' if j == 0 else '')
    ax.get_legend().remove()

plt.suptitle('RLCT Estimation: Bias and RMSE by Hyperparameters', y=1.02)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Compute summary statistics
summary = rlct_estimates_df.groupby(['dsid', 'n', 'hypers']).agg(
    mean_rlct=('rlct', 'mean'),
    std_rlct=('rlct', 'std')
).reset_index()

summary['true_rlct'] = summary['dsid'].apply(rlct_by_dsid)
summary['std_normalized'] = summary['std_rlct'] * np.sqrt(np.log(summary['n']))

dsids = ['regular', 'e-singular', 'singular1', 'singular2']
hypers_list = summary['hypers'].unique()
palette = sns.color_palette('Set2', len(hypers_list))
hyper_colors = dict(zip(hypers_list, palette))

n_range = np.array(sorted(summary['n'].unique()))

fig, axes = plt.subplots(2, len(dsids), figsize=(4*len(dsids), 8), sharex=True)

for j, dsid in enumerate(dsids):
    data = summary[summary['dsid'] == dsid]
    
    # Top row: Std with reference line
    ax = axes[0, j]
    
    for hyper in hypers_list:
        hdata = data[data['hypers'] == hyper].sort_values('n')
        ax.plot(hdata['n'], hdata['std_rlct'], 'o-', 
                label=hyper, color=hyper_colors[hyper])
    
    # Reference line anchored at midpoint
    mid_idx = len(n_range) // 2
    ref_n = n_range[mid_idx]
    ref_std = data.groupby('n')['std_rlct'].mean().iloc[mid_idx]
    
    ax.plot(n_range, ref_std * (np.log(ref_n) / np.log(n_range)), 
            'k:', alpha=0.4, linewidth=2, label='1/log(n)')
    
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('')
    ax.set_ylabel('Std(λ̂)' if j == 0 else '')
    ax.set_title(dsid, fontweight='bold')
    
    if j == len(dsids) - 1:
        ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
    
    # Bottom row: Std × √log(n)
    ax = axes[1, j]
    
    for hyper in hypers_list:
        hdata = data[data['hypers'] == hyper].sort_values('n')
        ax.plot(hdata['n'], hdata['std_normalized'], 'o-', 
                label=hyper, color=hyper_colors[hyper])
    
    ax.set_xscale('log')
    ax.set_xlabel('n')
    ax.set_ylabel('Std × √log(n)' if j == 0 else '')
    ax.get_legend().remove() if ax.get_legend() else None

plt.suptitle('RLCT Convergence Rate (flat bottom row confirms 1/√log(n))', y=1.02)
plt.tight_layout()
plt.show()
