# %%
# Adjust the working directly to import packages using the root package
import sys
import os

notebook_dir = os.getcwd()
print(notebook_dir)
parent_dir = os.path.dirname(notebook_dir)
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import sys
print(sys.executable)
# Out:
# /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/notebooks
# /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/.venv/bin/python3

# %%
import sys
print(sys.executable)

import subprocess
result = subprocess.run([sys.executable, "-m", "pip", "list"], capture_output=True, text=True)
print(result.stdout)
# Out:
# /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/.venv/bin/python3

# %%
from sklearn_extensions.mixture import BinomialMixture
import pytensor
import pytensor.tensor as pt

bmm = BinomialMixture(name="bmm", w=[0.1, 0.9], prob=[0.1, 0.3], n_trials=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import pytensor
#       3 import pytensor.tensor as pt
# ----> 5 bmm = BinomialMixture(name="bmm", w=[0.1, 0.9], prob=[0.1, 0.3], n_trials=100)
#
# TypeError: BinomialMixture.__init__() got an unexpected keyword argument 'name'
