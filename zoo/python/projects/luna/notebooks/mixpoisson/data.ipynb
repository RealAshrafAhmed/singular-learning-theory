# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
from os import environ


ROOT = Path(f"{Path.cwd().parents[1]}/outputs")
basedir = Path(f"{ROOT}/mixpoisson")
outputdir = Path(f"{basedir}/data")

if not outputdir.exists():
  outputdir.mkdir(exist_ok=True)
  print(f"Created {outputdir}!")

print(f"Using outputdir={outputdir}")
# Out:
# Using outputdir=/Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import seaborn as sns
import numpy as np
import pandas as pd

# from sklearn_extension.mixture import PoissonMixture
from sklearn.utils import resample

from IPython.display import display, clear_output
from tqdm.notebook import tqdm

from joblib import Parallel, delayed
import multiprocessing as mp
# from plot import visualize_joint_confidence_regions
import seaborn as sns
from matplotlib.lines import Line2D
import math

default_palette = "tab10"
# Enable LaTeX rendering
plt.rcParams["text.usetex"] = True
plt.rcParams["text.latex.preamble"] = r"\usepackage{amsmath}"

# %%
dgps_file = Path(f"{outputdir}/dgp.csv")
if dgps_file.exists():  # check if this data has already been generated
    print(f"File {dgps_file} exists, skipping experiments meta!.")
else:
    if dgps_file.parent:  # create parents dir if not already
        dgps_file.parent.mkdir(parents=True, exist_ok=True)

    dsids = ["regular", "e-singular", "singular1", "singular2"]
    dgps_raw = {
        "dsid": dsids,
        "m0": np.array([15, 10, 10, 5]),
        "m1": np.array([1, 5, 5, 5]),
        "w0": np.array(
            [0.75, 0.75, 1, 0.75]
        ),
    }
    dgps_raw["w1"] = 1 - dgps_raw["w0"]
    pd.DataFrame(dgps_raw).set_index("dsid").to_csv(dgps_file)
    print(f"File {dgps_file} created!.")

dgps = pd.read_csv(dgps_file, index_col=0).reset_index()
dgps.head()
# Out:
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/dgp.csv created!.
#          dsid  m0  m1    w0    w1
# 0     regular  15   1  0.75  0.25
# 1  e-singular  10   5  0.75  0.25
# 2   singular1  10   5  1.00  0.00
# 3   singular2   5   5  0.75  0.25

# %%
from sklearn_extensions.mixture import mixpoisson_sample

num_replications = 1000  # number of samples per sample size
regimes = range(50, 5000+50, 50)

for dsid in dgps["dsid"].unique():
  for regime in regimes:
    obs_file = Path(
        f"{outputdir}/{dsid}-{regime}.csv"
    )  # where we are going to store observations
    if obs_file.exists():  # check if this data has already been generated
        print(f"File {obs_file} exists, skipping random samples creation!.")
    else:
        if obs_file.parent:  # create parents dir if not already
            obs_file.parent.mkdir(parents=True, exist_ok=True)
  
        results = {}
        for i in range(num_replications):
            dgp = dgps.query(f"dsid=='{dsid}'")
            mus = dgp[["m0", "m1"]].iloc[0].tolist()
            weights = dgp[["w0", "w1"]].iloc[0].tolist()
            samples = mixpoisson_sample(size=regime, weights=weights, mus=mus)
            results[f"r{i}"] = samples[0]
  
        data_df = pd.DataFrame(results)
        data_df.to_csv(obs_file, index=False)
        print(f"File {obs_file} created!.")


dsids = dgps["dsid"]
data = {}
for dsid in dsids:
  data[dsid]={}
  for regime in regimes:
    data[dsid][regime] = pd.read_csv(
        f"{outputdir}/{dsid}-{regime}.csv", index_col=0
    ).reset_index()
  
print(f"loaded {list(data.keys())} samples")
# Out:
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/regular
csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3000.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3050.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3100.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3150.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3200.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3250.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3300.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3350.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3400.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3450.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3500.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3550.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3600.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3650.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3700.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3750.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3800.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3850.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3900.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-3950.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular1-4000.csv exists, skipping random samples creation!.
# ...
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-450.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-500.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-550.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-600.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-650.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-700.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-750.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-800.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-850.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-900.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-950.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1000.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1050.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1100.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1150.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1200.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1250.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1300.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1350.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1400.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1450.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1500.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1550.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1600.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1650.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1700.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1750.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1800.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1850.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1900.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-1950.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2000.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2050.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2100.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2150.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2200.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2250.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2300.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2350.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2400.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2450.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2500.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2550.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2600.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2650.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2700.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2750.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2800.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2850.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2900.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-2950.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3000.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3050.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3100.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3150.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3200.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3250.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3300.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3350.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3400.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3450.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3500.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3550.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3600.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3650.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3700.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3750.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3800.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3850.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3900.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-3950.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4000.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4050.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4100.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4150.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4200.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4250.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4300.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4350.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4400.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4450.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4500.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4550.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4600.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4650.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4700.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4750.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4800.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4850.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4900.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-4950.csv exists, skipping random samples creation!.
# File /Users/ashrafahmed/workspace/waterloo-slt-reading-group/zoo/python/projects/luna/outputs/mixpoisson/data/singular2-5000.csv exists, skipping random samples creation!.
# loaded ['regular', 'e-singular', 'singular1', 'singular2'] samples

# %%
datasets = dgps["dsid"].unique()

# plot the data sets as different sample sizes
# we need to structure the plotting data for different sample sizes (keeping in mind that we are not regenerating the sample in each sample size)
plotdata = {"x": [], "size": [], "dsid": []} # raw data to initialize the plotting dataframe

regimes_to_plot = [50, 250, 5000]

for dsid in datasets:
    dgp = dgps.query(f"dsid == '{dsid}'")
    for ss in regimes_to_plot:
        x = data[dsid][5000].iloc[:ss,1]
        plotdata["x"]=np.append(plotdata["x"], x)
        plotdata["size"]=np.append(plotdata["size"], (np.ones(ss)*ss).astype(int))
        plotdata["dsid"]=np.append(plotdata["dsid"], [dsid for i in np.ones(ss)])

plotdf = pd.DataFrame(plotdata)
plotdf = plotdf.astype({"x": int, "size": int, "dsid": str})
g=sns.displot(plotdf,
              x="x", col="size", row="dsid", hue="dsid",
              binwidth=3, height=3, facet_kws={"margin_titles": True, "sharey": False}, legend=False, palette=default_palette)

g.set_axis_labels("Songs per unit time", "Frequency")
g.set_titles(col_template="Total Samples: {col_name}", row_template=f"{{row_name}}")

for ax in g.axes.flat:
    ax.set_xticks(list(range(0, 40, 5)))

datasets_hist_file = Path(f'{outputdir}/dataset_hist.png')
if datasets_hist_file.parent: # create parents dir if not already
    datasets_hist_file.parent.mkdir(parents=True, exist_ok=True)

plt.savefig(datasets_hist_file, dpi=300, bbox_inches='tight')
plt.show()
